# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("milknew.csv")

# %%
df
# Out:
#        pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
# 0     6.6          35      1     0     1          0     254    high
# 1     6.6          36      0     1     0          1     253    high
# 2     8.5          70      1     1     1          1     246     low
# 3     9.5          34      1     1     0          1     255     low
# 4     6.6          37      0     0     0          0     255  medium
# ...   ...         ...    ...   ...   ...        ...     ...     ...
# 1054  6.7          45      1     1     0          0     247  medium
# 1055  6.7          38      1     0     1          0     255    high
# 1056  3.0          40      1     1     1          1     255     low
# 1057  6.8          43      1     0     1          0     250    high
# 1058  8.6          55      0     1     1          1     255     low
#
# [1059 rows x 8 columns]

# %%
df.head()
# Out:
#     pH  Temprature  Taste  Odor  Fat   Turbidity  Colour   Grade
# 0  6.6          35      1     0     1          0     254    high
# 1  6.6          36      0     1     0          1     253    high
# 2  8.5          70      1     1     1          1     246     low
# 3  9.5          34      1     1     0          1     255     low
# 4  6.6          37      0     0     0          0     255  medium

# %%
df.columns
# Out:
# Index(['pH', 'Temprature', 'Taste', 'Odor', 'Fat ', 'Turbidity', 'Colour',
#        'Grade'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# pH            0
# Temprature    0
# Taste         0
# Odor          0
# Fat           0
# Turbidity     0
# Colour        0
# Grade         0
# dtype: int64

# %%
df.dtypes
# Out:
# pH            float64
# Temprature      int64
# Taste           int64
# Odor            int64
# Fat             int64
# Turbidity       int64
# Colour          int64
# Grade          object
# dtype: object

# %%
import seaborn as sns

# %%
sns.countplot(x = 'pH',data=df)
# Out:
# <AxesSubplot:xlabel='pH', ylabel='count'>

# %%
sns.countplot(x = 'Grade',data=df)
# Out:
# <AxesSubplot:xlabel='Grade', ylabel='count'>

# %%
target= df['Grade']
df = df.drop('Grade',axis=1)
df
# Out:
#        pH  Temprature  Taste  Odor  Fat   Turbidity  Colour
# 0     6.6          35      1     0     1          0     254
# 1     6.6          36      0     1     0          1     253
# 2     8.5          70      1     1     1          1     246
# 3     9.5          34      1     1     0          1     255
# 4     6.6          37      0     0     0          0     255
# ...   ...         ...    ...   ...   ...        ...     ...
# 1054  6.7          45      1     1     0          0     247
# 1055  6.7          38      1     0     1          0     255
# 1056  3.0          40      1     1     1          1     255
# 1057  6.8          43      1     0     1          0     250
# 1058  8.6          55      0     1     1          1     255
#
# [1059 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df,target,test_size =0.20,random_state=12)

X_train.head()
# Out:
#       pH  Temprature  Taste  Odor  Fat   Turbidity  Colour
# 655  6.7          38      1     0     1          0     255
# 37   7.4          65      0     0     0          0     255
# 468  6.6          35      0     1     1          1     255
# 326  6.8          45      0     1     1          1     255
# 241  6.6          38      0     0     0          0     255

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[ 0.05113209, -0.63089999,  0.91941063, ...,  0.69898244,
#         -0.98709623,  0.72716139],
#        [ 0.55139972,  2.09806766, -1.0876533 , ..., -1.43065111,
#         -0.98709623,  0.72716139],
#        [-0.02033471, -0.93411862, -1.0876533 , ...,  0.69898244,
#          1.01307245,  0.72716139],
#        ...,
#        [-0.09180151, -0.73197287, -1.0876533 , ..., -1.43065111,
#         -0.98709623,  0.72716139],
#        [ 2.05220259, -1.0351915 ,  0.91941063, ..., -1.43065111,
#          1.01307245,  0.72716139],
#        [ 1.40900136,  1.0873389 , -1.0876533 , ...,  0.69898244,
#          1.01307245,  0.72716139]])

# %%
X_train = pd.DataFrame(X_train)
X_test = pd.DataFrame(X_test)

# %%
X_train.iloc[81]
# Out:
# 0    0.122599
# 1    0.076610
# 2    0.919411
# 3    1.116550
# 4    0.698982
# 5   -0.987096
# 6   -1.590016
# Name: 81, dtype: float64

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import classification_report

# %%
y_predict= model.predict(X_test)
y_actual=y_test
y_predict
# Out:
# array(['high', 'low', 'medium', 'low', 'medium', 'medium', 'low',
#        'medium', 'low', 'medium', 'low', 'high', 'low', 'high', 'medium',
#        'low', 'low', 'medium', 'medium', 'medium', 'high', 'high', 'high',
#        'high', 'high', 'medium', 'low', 'high', 'medium', 'medium',
#        'high', 'low', 'low', 'high', 'medium', 'low', 'medium', 'low',
#        'high', 'low', 'medium', 'low', 'low', 'low', 'high', 'high',
#        'medium', 'low', 'low', 'high', 'high', 'medium', 'low', 'medium',
#        'low', 'medium', 'low', 'low', 'low', 'medium', 'low', 'low',
#        'low', 'medium', 'high', 'low', 'medium', 'high', 'high', 'high',
#        'high', 'medium', 'low', 'low', 'low', 'high', 'low', 'medium',
#        'high', 'high', 'low', 'medium', 'low', 'medium', 'low', 'medium',
#        'medium', 'medium', 'low', 'medium', 'low', 'high', 'medium',
#        'high', 'low', 'high', 'low', 'low', 'low', 'low', 'high', 'high',
#        'medium', 'high', 'medium', 'low', 'low', 'low', 'low', 'low',
#        'low', 'low', 'medium', 'low', 'medium', 'high', 'low', 'medium',
#        'low', 'low', 'medium', 'high', 'medium', 'low', 'low', 'medium',
#        'high', 'medium', 'low', 'high', 'low', 'low', 'high', 'medium',
#        'medium', 'low', 'medium', 'medium', 'high', 'medium', 'low',
#        'medium', 'low', 'medium', 'medium', 'low', 'high', 'medium',
#        'low', 'low', 'high', 'medium', 'high', 'high', 'high', 'medium',
#        'low', 'high', 'medium', 'low', 'low', 'high', 'high', 'medium',
#        'high', 'low', 'high', 'high', 'medium', 'low', 'low', 'low',
#        'high', 'medium', 'medium', 'low', 'medium', 'low', 'medium',
#        'low', 'low', 'medium', 'low', 'medium', 'medium', 'low', 'low',
#        'low', 'low', 'low', 'low', 'high', 'medium', 'low', 'high', 'low',
#        'medium', 'high', 'high', 'low', 'medium', 'medium', 'low', 'high',
#        'low', 'low', 'low', 'high', 'medium', 'medium', 'medium',
#        'medium'], dtype=object)

# %%
y_actual
# Out:
# 50        high
# 13         low
# 1054    medium
# 711     medium
# 569     medium
#          ...
# 386       high
# 595     medium
# 1029    medium
# 721     medium
# 929     medium
# Name: Grade, Length: 212, dtype: object

# %%
print(classification_report(y_actual,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#         high       0.78      0.86      0.82        49
#          low       0.87      0.92      0.89        84
#       medium       0.94      0.82      0.88        79
#
#     accuracy                           0.87       212
#    macro avg       0.86      0.87      0.86       212
# weighted avg       0.87      0.87      0.87       212

# %%
sns.heatmap(X_train.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

tr_comp = pca.fit_transform(X_train)
ts_comp = pca.fit_transform(X_test)

# %%
tr_comp
# Out:
# array([[ 0.33410601, -1.19199081],
#        [ 2.04866251,  1.70811144],
#        [-1.36399969, -0.00721637],
#        ...,
#        [ 1.99286135, -0.52812705],
#        [-0.34903145,  0.69083723],
#        [-1.17970468,  2.16297551]])

# %%
from sklearn.linear_model import LogisticRegression
pc_model = LogisticRegression()
pc_model.fit(tr_comp,y_train)
# Out:
# LogisticRegression()

# %%
y_predict=pc_model.predict(ts_comp)
y_predict
# Out:
# array(['high', 'low', 'medium', 'low', 'medium', 'medium', 'low',
#        'medium', 'low', 'medium', 'low', 'low', 'medium', 'medium',
#        'medium', 'low', 'high', 'medium', 'medium', 'medium', 'high',
#        'low', 'high', 'low', 'high', 'medium', 'low', 'high', 'medium',
#        'medium', 'medium', 'low', 'low', 'low', 'medium', 'low', 'low',
#        'low', 'medium', 'low', 'medium', 'high', 'high', 'low', 'low',
#        'medium', 'medium', 'low', 'low', 'low', 'high', 'medium', 'low',
#        'medium', 'low', 'medium', 'low', 'low', 'low', 'medium', 'low',
#        'low', 'low', 'medium', 'low', 'low', 'medium', 'high', 'low',
#        'low', 'medium', 'medium', 'medium', 'low', 'low', 'low', 'low',
#        'medium', 'medium', 'medium', 'low', 'medium', 'low', 'medium',
#        'low', 'medium', 'medium', 'medium', 'low', 'medium', 'low', 'low',
#        'medium', 'high', 'low', 'high', 'medium', 'high', 'high',
#        'medium', 'high', 'high', 'medium', 'medium', 'medium', 'low',
#        'low', 'low', 'low', 'medium', 'medium', 'low', 'medium', 'low',
#        'medium', 'medium', 'high', 'medium', 'low', 'low', 'medium',
#        'low', 'medium', 'low', 'low', 'medium', 'low', 'medium', 'low',
#        'medium', 'low', 'low', 'medium', 'medium', 'medium', 'low',
#        'medium', 'medium', 'low', 'medium', 'low', 'medium', 'high',
#        'medium', 'low', 'low', 'medium', 'medium', 'low', 'low', 'high',
#        'medium', 'medium', 'high', 'low', 'low', 'low', 'medium',
#        'medium', 'medium', 'low', 'medium', 'low', 'medium', 'high',
#        'low', 'low', 'low', 'low', 'medium', 'low', 'low', 'high',
#        'medium', 'medium', 'medium', 'medium', 'low', 'medium', 'low',
#        'low', 'medium', 'low', 'medium', 'medium', 'low', 'low', 'low',
#        'low', 'medium', 'high', 'medium', 'medium', 'low', 'medium',
#        'low', 'medium', 'low', 'low', 'high', 'medium', 'medium', 'low',
#        'low', 'low', 'low', 'low', 'low', 'medium', 'medium', 'medium',
#        'medium'], dtype=object)

# %%
y_actual=y_test
print(classification_report(y_actual,y_predict))
# Out:
#               precision    recall  f1-score   support
#
#         high       0.62      0.31      0.41        49
#          low       0.67      0.76      0.71        84
#       medium       0.75      0.87      0.81        79
#
#     accuracy                           0.70       212
#    macro avg       0.68      0.65      0.64       212
# weighted avg       0.69      0.70      0.68       212

# %%
# Get the principal components directly from pca.components_
principal_components = pca.components_
print("Principal Components:")
print(principal_components)
# Out:
# Principal Components:
# [[-0.05830757 -0.25109993 -0.29600566 -0.43491266 -0.52171391 -0.58820656
#   -0.19649002]
#  [ 0.51926361  0.68854561 -0.32898208 -0.10157604 -0.23584325  0.17913848
#   -0.22363075]]
